# %%
from utils.Selector import ImgSelector
import pickle
import numpy as np

# %%
with open('tmp/imgs.pkl', 'rb') as f:
    imgs = pickle.load(f)
mtx = np.load('tmp/feature_matrix.npy')
model = ImgSelector(imgs, mtx)
# Out:
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %% [markdown]
# # Search Image

# %%
model.search("a plane flying in the sky .", k=10)
